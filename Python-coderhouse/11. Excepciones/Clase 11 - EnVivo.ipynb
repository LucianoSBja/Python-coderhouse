# %% [markdown]
# # Errores sintácticos

# %%
"""
Errores por no seguir el lenguaje que entiende Python
Usualmente, son detectados por el editor de código
"""
# nombre
# no cerrar parentesis
# no colocar dos puntos
# mala indentación
# llamar metodos que no tiene una clase

# %%
print(variable_nueva)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51a1adfc3d8e> in <cell line: 1>()
# ----> 1 print(variable_nueva)
#
# NameError: name 'variable_nueva' is not defined

# %%
# Parentesis faltante
6 + (2 + 3

# %%
# indentacion irregular
num = 100

if num > 10:
    print(num)
   print("hola")
# Out:
#   File "<tokenize>", line 6
#     print("hola")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
lista = [2, 3, 4]

# %%
# llamar metodos que no tiene una clase
lista.add(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8e1979b66f84> in <cell line: 2>()
#       1 # llamar metodos que no tiene una clase
# ----> 2 lista.add(20)
#
# AttributeError: 'list' object has no attribute 'add'

# %% [markdown]
# ## Errores semánticos

# %%
lista = [30, 20, 10]

# %%
retorno = lista.pop()
retorno
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-14723dbb5a18> in <cell line: 1>()
# ----> 1 retorno = lista.pop()
#       2 retorno
#
# IndexError: pop from empty list

# %%
# Para evitar ese error podemos
if len(lista) > 0:
    retorno = lista.pop()
    print(retorno)

# %%
num1 = int(input("Numero 1: "))
num2 = int(input("Numero 2: "))

cociente = num1 / num2
print(cociente)
# Out:
# Numero 1: 10
# Numero 2: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-42f05079bb33> in <cell line: 4>()
#       2 num2 = int(input("Numero 2: "))
#       3
# ----> 4 cociente = num1 / num2
#       5 print(cociente)
#
# ZeroDivisionError: division by zero

# %%
num1 = int(input("Numero 1: "))
num2 = int(input("Numero 2: "))

if num2 != 0:
    cociente = num1 / num2
else:
    cociente = None
print(cociente)
# Out:
# Numero 1: 10
# Numero 2: 0
# None

# %%
if cociente is None:
    print("No aplica")
# Out:
# No aplica

# %% [markdown]
# # Excepciones

# %% [markdown]
# Las excepciones son errores operacionales que ocurren durante la ejecución de mi código.
# Ocurren para ciertos argumentos en ciertas ocasiones

# %%
20/4

# %%
# DivisionByZero
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-24-117c486e33e5> in <cell line: 2>()
#       1 # DivisionByZero
# ----> 2 10/0
#
# ZeroDivisionError: division by zero

# %%
int("30")
# Out:
# 30

# %%
# ValueError
int("hola")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a33e099125d9> in <cell line: 2>()
#       1 # ValueError
# ----> 2 int("hola")
#
# ValueError: invalid literal for int() with base 10: 'hola'

# %%
# index out of range
lista = [10, 20, 30, 40]

# %%
lista[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-f715f6e228b7> in <cell line: 1>()
# ----> 1 lista[6]
#
# IndexError: list index out of range

# %% [markdown]
# # Bloques try-except
# Los bloques try-except nos permiten poder continuar con la ejecución de un programa aunque ocurra un error.
#
# Para prevenir el posible fallo debemos poner el código que puede fallar dentro de un bloque try y luego encadenar otro bloque except para tratar la situación excepcional y procesarla.

# %%
#Ejemplo sin error
a = 7
b = 10

try:
    print("Entrando en el try")
    suma = a + b
    print(suma)
    print("Terminando en el try")
except:
    print("Ha ocurrido un error al sumar.")

print("Ejecución exitosa")
# Out:
# Entrando en el try
# 17
# Terminando en el try
# Ejecución exitosa

# %%
5 + "hola"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-7143cfcaabe4> in <cell line: 1>()
# ----> 1 5 + "hola"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Ejemplo con error
a = 7
b = "texto"

try:
    print("Entrando en el try")
    suma = a + b
    print(suma)
    print("Terminando el try")
except:  # Este es una excepción generica, captura excepción
    print("Ha ocurrido un error al sumar.")

print("Termino la ejecucion")
# Out:
# Entrando en el try
# Ha ocurrido un error al sumar.
# Termino la ejecucion

# %% [markdown]
# La sentencia try funciona de la siguiente manera:
#
# * Se ejecuta el bloque try (el código entre las sentencias try y except).
#
# * Si no ocurre ninguna excepción, el bloque except se saltea y termina la ejecución de la sentencia try.
#
# Como vemos esta forma nos permite controlar situaciones excepcionales que generalmente darían error y en su lugar mostrar un mensaje o ejecutar una pieza de código alternativo.

# %% [markdown]
# ## Ejemplos de uso

# %% [markdown]
# Podemos aprovechar las excepciones para, por ejemplo, forzar al usuario a introducir dos números haciendo uso de un bucle while, repitiendo los inputs hasta que lo haga bien y entonces romper el bucle con un break:

# %%
float("dos")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-2b88ff3e7802> in <cell line: 1>()
# ----> 1 float("dos")
#
# ValueError: could not convert string to float: 'dos'

# %%
float("2.5")
# Out:
# 2.5

# %%
while True:
    try:
        a = float(input("Introduce un número: "))
        b = float(input("Introduce otro número: "))
        print("Ingresaste bien los dos numeros")
        suma = a + b
        break
    except:
        print("Ha ocurrido un error. Tienes que introducir 2 números. Vuelvelo a intentar")

print(f"La suma es {suma}")
# Out:
# Introduce un número: uno
# Ha ocurrido un error. Tienes que introducir 2 números. Vuelvelo a intentar
# Introduce un número: 2.21
# Introduce otro número: dos
# Ha ocurrido un error. Tienes que introducir 2 números. Vuelvelo a intentar
# Introduce un número: 3
# Introduce otro número: 4.1
# Ingresaste bien los dos numeros
# La suma es 7.1

# %% [markdown]
# Entonces en definitiva....
#
# **Try - Except nos permite controlar situaciones excepcionales que generalmente darían error y en su lugar permite mostrar un mensaje o ejecutar una pieza de código alternativo.**

# %%
# Ejemplo 2
"""
Juan tiene 6 años y quiere un cumpleaños en un parque.
Debe invitar exactamente a 3 amig@s. Cada invitado debe tener nombre y edad en numeros
"""
lista_invitados = []

# %%
for i in range(3):
    try:
        nombre = input("Nombre del invitado: ")
        edad = int(input("Edad del invitado: "))
        invitado_diccionario = {"edad": edad, "nombre": nombre}
        lista_invitados.append(invitado_diccionario)
    except:
        print("Ha ocurrido un error. La edad debe ser un número entero.")
        # Debemos limpiar la lista para empezar con lista vacia el for
        lista_invitados = []
        break

# %% [markdown]
# # Bloque try, except, else
#
# Es posible encadenar un bloque else después del except para comprobar el caso en que todo funcione correctamente (no se ejecuta la excepción). El bloque else es un buen momento para romper la iteración con break si todo funciona correctamente:

# %%
while True:
    try:
        a = float(input("Introduce un número: "))
        b = float(input("Introduce otro número: "))
        suma = a + b
    except:
        print("Ha ocurrido un error. Tienes que introducir 2 números.")
    else:
        # Se ejecuta si el bloque try no arrojo errores
        print("La suma se ha realizado correctamente.")
        print(f"La suma es {suma}")
        break  # Importante romper la iteración si todo ha ido bien.
# Out:
# Introduce un número: 3
# Introduce otro número: dos
# Ha ocurrido un error. Tienes que introducir 2 números.
# Introduce un número: 2
# Introduce otro número: 5
# La suma se ha realizado correctamente.
# La suma es 7.0

# %% [markdown]
# # Bloque try, except, else, finally
#
# Por último es posible utilizar un bloque finally que se ejecute al final del código, ocurra o no ocurra un error:

# %%
# Ejemplo 1

while True:
    try:
        a = float(input("Introduce un número: "))
        b = float(input("Introduce otro número: "))
        suma = a + b
    except:
        print("Ha ocurrido un error. Tienes que introducir 2 números.")
    else:
        # Se ejecuta si el bloque try no arrojo errores
        print("La suma se ha realizado correctamente.")
        print(f"La suma es {suma}")
        break   # Importante romper la iteración si todo ha ido bien.
    finally:
        # Es como un after credits
        # Esto se ejecuta siempre. inclusive despúes de un break
        # Se usa para acciones de limpieza
        print("Finally, para limpieza")
# Out:
# Introduce un número: 5
# Introduce otro número: 2
# La suma se ha realizado correctamente.
# La suma es 7.0
# Finally, para limpieza

# %% [markdown]
# ## Ejemplos vida real en pygsheets

# %% [markdown]
# # Capturar excepciones por tipo
# # Excepciones multiples
#
# En un mismo fragmento de código pueden ocurrir muchos errores diferentes y quizá nos interese actuar de forma diferente en cada caso. Para esas situaciones algo que podemos hacer es asignar una excepción a una variable. De esta forma es posible analizar el tipo de error que sucede gracias a su identificador.
#
# Imaginemos un ejemplo en el que queremos dividir 20 entre un número que el usuario introduce por teclado (20 / numero). Pueden ocurrir varios tipos de errores: que el usuario introduzca una cadena, que introduzca un cero... Vamos a asignar la excepción a una variable y así veremos el tipo de error que se produce.

# %%
# recordando
float("dos")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-90c0b795ee15> in <cell line: 2>()
#       1 # recordando
# ----> 2 float("dos")
#
# ValueError: could not convert string to float: 'dos'

# %%
float("*")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-91660093a9a1> in <cell line: 1>()
# ----> 1 float("*")
#
# ValueError: could not convert string to float: '*'

# %%
def ejemplo_division():
    constante = 5
    try:
        num = float(input("Introduce un número divisor: "))
        cociente = constante/num
        print(cociente)
    except ValueError as e:
        print("No se puede dividir el número entre una cadena de texto")
        print(f"Mensaje de error arrojado por python fue: {e}")
    except ZeroDivisionError as e:
        print("No se puede dividir por cero, prueba otro número")
    except Exception as e:
        # Nos sirve para capturar errores no previstos
        # Comodin
        print("Ha ocurrido un error no previsto:", type(e).__name__ )

# %%
ejemplo_division()
# Out:
# Introduce un número divisor: dos
# No se puede dividir el número entre una cadena de texto
# Mensaje de error arrojado por python fue: could not convert string to float: 'dos'

# %% [markdown]
# # Forzar error con raise
#
# A veces necesitas forzar el error para parar la ejecución del código. Sirve cuando: parar ejecución, código aguas arriba maneje la excepción, y software de monitoreo de errores

# %%
def ejemplo_division_2():
    constante = 5
    try:
        num = float(input("Introduce un número divisor: "))
        return constante/num
    except ValueError as e:
        print("No se puede dividir el número entre una cadena")
        raise
    except ZeroDivisionError as e:
        print("No se puede dividir por cero, prueba otro número")
        raise
    except Exception as e:
        # Nos sirve para capturar errores no previstos
        print("Ha ocurrido un error no previsto", type(e).__name__ )
        raise

# %%
ejemplo_division_2()
# Out:
# Introduce un número divisor: dos
# No se puede dividir el número entre una cadena
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-3d8251cd35e4> in <cell line: 1>()
# ----> 1 ejemplo_division_2()
#
# <ipython-input-15-386d37b6e384> in ejemplo_division_2()
#       2     constante = 5
#       3     try:
# ----> 4         num = float(input("Introduce un número divisor: "))
#       5         return constante/num
#       6     except ValueError as e:
#
# ValueError: could not convert string to float: 'dos'

# %% [markdown]
# # Crear tus propios errores

# %%
# Ejemplo vida real: Pygsheets

# %%
class ErrorAutenticacion(Exception):
    pass

# %%
# la base de datos almacena usuario: contraseña

base_datos = {
    "pedro": "1234ab",
    "paco": "contra123",
}

# %%
def chequear_credenciales(username, password, base_datos):
    password_en_mi_base_datos = base_datos[username]
    if password_en_mi_base_datos == password:
        return True  # Significa que la contraseña es correcta
    else:
        # Contraseña incorrecta
        # Disparo el error con raise
        raise ErrorAutenticacion("Username o contraseña no coinciden")

# %%
chequear_credenciales("pedro", "1234ab", base_datos)
# Out:
# True

# %%
chequear_credenciales("pedro", "1234", base_datos)
# Out:
# ---------------------------------------------------------------------------
# ErrorAutenticacion                        Traceback (most recent call last)
# <ipython-input-22-6a81749b4ba4> in <cell line: 1>()
# ----> 1 chequear_credenciales("pedro", "1234", base_datos)
#
# <ipython-input-19-ca4b39270b69> in chequear_credenciales(username, password, base_datos)
#       6         # Contraseña incorrecta
#       7         # Disparo el error con raise
# ----> 8         raise ErrorAutenticacion("Username o contraseña no coinciden")
#
# ErrorAutenticacion: Username o contraseña no coinciden
