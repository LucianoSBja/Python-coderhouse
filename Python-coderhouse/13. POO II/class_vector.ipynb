# %%
class Vector:
    """
    Clase Vector con caracteristicas similares a una lista.
    Pero contiene lógica y métodos adicionales.
    """
    def __init__(self, data, titulo):
        self._data = data  # atributo privado. Es decir el desarrollador no recomienda acceder a él externamente
        self.titulo = titulo

    def __str__(self) -> str:
        # logica modificada que no tiene la lista
        return f"Vector cuyos valores son {self._data}"

    def __len__(self):
        return len(self._data)

    def __getitem__(self, pos):
        return self._data[pos]

    def __setitem__(self, pos, value):
        self._data[pos] = value

    def __iter__(self):
        for pos in range(0, len(self._data)):
            yield self._data[pos]

    # Aqui viene la logica adicional
    def calcular_product(self):
        return "Calculando el producto"

    def agregar(self, elem):
        self._data.append(elem)

# %%
vector_1 = Vector(data=[1,2], titulo="Titulo 1")

# %%
vector_1._data
# Out:
# [1, 2]

# %%
vector_1.__len__()
# Out:
# 2

# %%
# Python entiende que len() debe llamar al magic method __len__
len(vector_1)
# Out:
# 2

# %%
vector_1.__str__()
# Out:
# 'Vector cuyos valores son [1, 2]'

# %%
print(vector_1)
# Out:
# Vector cuyos valores son [1, 2]

# %%
# Obtener el elemento en la posicion 1
vector_1.__getitem__(1)
# Out:
# 2

# %%
vector_1[1]
# Out:
# 2

# %%
vector_1.__setitem__(1, 10)

# %%
print(vector_1)
# Out:
# Vector cuyos valores son [1, 20]

# %%
vector_1[1] = 20

# %%
# Mis metodos personalizados
vector_1.agregar(200)

# %%
vector_1._data
# Out:
# [1, 20, 200]

# %%
for elem in vector_1:
    print(elem)

# %%
vector_1.calcular_product()
