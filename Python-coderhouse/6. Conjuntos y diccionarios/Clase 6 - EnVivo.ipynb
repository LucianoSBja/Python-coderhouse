# %% [markdown]
# # Set!

# %%
conjunto_alumnos = {'Emanuel', 'Ivan', 'Diego', 'Natalia', 'Jorge'}

# %%
type(conjunto_alumnos)
# Out:
# set

# %%
conjunto_alumnos
# Out:
# {'Diego', 'Emanuel', 'Ivan', 'Jorge', 'Natalia'}

# %%
# Algunas veces los sets (conjuntos) parecen ordenados cuando los imprimes o retornas, pero un conjunto nunca está ordenado.
# Que los conjuntos no esten ordenados significa que la definición de conjunto en Python no asegura un orden
# Python suele imprimir conjuntos "pequeños" como si estuvieran ordenados, pero NO lo están!!!
# Cualquier orden aparente es una particularidad del interprete de Python que estes usando, de la cual no puedes depender

# %%
import random

# Generemos 50 numeros al azar del 1 al 1000
random_numbers = random.sample(range(1, 1001), 50)

# Convert the random numbers to a set to remove duplicates
random_numbers = set(random_numbers)

# Print the random numbers
print(random_numbers)
# Out:
# {647, 905, 907, 652, 526, 403, 276, 789, 24, 25, 281, 668, 924, 40, 431, 561, 306, 56, 57, 443, 318, 576, 65, 449, 706, 707, 72, 329, 586, 716, 336, 849, 210, 722, 213, 341, 471, 984, 479, 96, 995, 1000, 251, 879, 626, 755, 120, 122, 379, 253}

# %%
conjunto_a = set()

# %%
conjunto_a
# Out:
# set()

# %%
type(conjunto_a)
# Out:
# set

# %%
conjunto_b = {}  # Esto no creara un conjunto vacio

# %%
# Asi se crea un diccionario vacio, no un conjunto
type(conjunto_b)
# Out:
# dict

# %%
conjunto_c = set(['Emanuel', 'Ivan', 'Diego', 'Natalia', 'Jorge'])

# %%
conjunto_c
# Out:
# {'Diego', 'Emanuel', 'Ivan', 'Jorge', 'Natalia'}

# %%
lista_ganadores = ["Juan", "Pedro", "Gaby", "Juan"]

# %%
# No queremos ganadores repetidos, entonces puedo crear un set
conjunto_ganadores = set(lista_ganadores)

# %%
conjunto_ganadores
# Out:
# {'Gaby', 'Juan', 'Pedro'}

# %%
# No puedes consultar elementos por indice
conjunto_ganadores[0]

# %%
# No se pueden rebanar o hacer slicing
conjunto_ganadores[0:2]

# %%
# Otro ejemplo!
conjunto1 = {1, 2,"Juan", "Juan"}

# %%
conjunto1
# Out:
# {1, 2, 'Juan'}

# %%
#Agregamos un elemento
conjunto1.add("Nadia")

# %%
conjunto1
# Out:
# {1, 2, 'Juan', 'Nadia'}

# %%
conjunto1.add("Juan")

# %%
conjunto1
# Out:
# {1, 2, 'Juan', 'Nadia'}

# %%
#Actualizamos un elemento
conjunto1.update([33, 12, "Miguel", "Nadia"])

# %%
conjunto1
# Out:
# {1, 12, 2, 33, 'Juan', 'Miguel', 'Nadia'}

# %%
#Eliminamos el valor 33
conjunto1.discard(33)

# %%
conjunto1
# Out:
# {1, 12, 2, 'Juan', 'Miguel', 'Nadia'}

# %%
#Tratamos de eliminar un elemento que no existe
conjunto1.discard("Pepe")

# %%
conjunto1
# Out:
# {1, 12, 2, 'Juan', 'Miguel', 'Nadia'}

# %%
conjunto1.remove("Pepe")  #me muestra un error

# %%
conjunto1
# Out:
# {1, 12, 2, 'Juan', 'Miguel', 'Nadia'}

# %%
# Chequear contencion o pertenencia
"Nico" in conjunto1
# Out:
# False

# %%
"Juan" in conjunto1
# Out:
# True

# %%
conjunto1
# Out:
# {1, 12, 2, 'Juan', 'Miguel', 'Nadia'}

# %%
conjunto1.pop()  # ejecutamos varias veces! nos muestra aleatoriamente los valores
# Out:
# 2

# %%
conjunto1
# Out:
# {12, 'Juan', 'Miguel', 'Nadia'}

# %%
len(conjunto1)
# Out:
# 4

# %% [markdown]
# ### Los sets se pueden iterar con un for

# %%
#Uso de la funcion: Set()
frutas = set(("manzana", "banana", "cherry"))
print(frutas)
# Out:
# {'cherry', 'manzana', 'banana'}

# %%
#Los sets son objetos iterables
for fruta in frutas:
  print(fruta)
# Out:
# cherry
# manzana
# banana

# %% [markdown]
# # Diccionarios

# %% [markdown]
# Un diccionario es una estructura de datos que almacena la información en forma de pares con una clave única y un valor asociado. Existen diferentes maneras de crear un diccionario, veamos los casos mas generales:

# %%
# Link es el personaje principal de Zelda
# cada par de elementos => llave: valor

link = {
    "nombre": "Link",
    "edad": 7,
    "vida_total": 10,  # corazones
    "vida_actual": 5,
    "color_vesturio": "verde",
    "lanza_fuego": False,
    "objetos": ["piedra", "espada", "escudo"]
}

# %%
link
# Out:
# {'nombre': 'Link',
#  'edad': 7,
#  'vida_total': 10,
#  'vida_actual': 5,
#  'lanza_fuego': False,
#  'objetos': ['piedra', 'espada', 'escudo']}

# %%
link["vida_actual"]
# Out:
# 5

# %%
# diccionario usado para traducir colores del español al ingles


# clave en español. Valor en ingles
# colores = {"amarillo": "yellow", "azul": "blue", "rojo": "red"}
colores = {
    "amarillo": "yellow",
    "rojo": "red",
    "azul": "blue"
}

# %% [markdown]
# Para acceder al valor de un elemento, podemos realizarlo de la siguiente manera

# %%
colores["amarillo"]
# Out:
# 'yellow'

# %%
colores["Amarillo"]

# %%
# Diccionario vacío inicializado con dict()
my_dict = dict()
# Diccionario vacío inicializado con llaves
my_dict = {}

# %%
edades = {"Juan": 26, "Esteban": 35, "Maria": 29}

# %%
edades
# Out:
# {'Juan': 26, 'Esteban': 35, 'Maria': 29}

# %%
# Asignar, es decir agregar nuevos pares clave valor
edades["Paco"] = 21

# %%
edades
# Out:
# {'Juan': 26, 'Esteban': 35, 'Maria': 29, 'Paco': 21}

# %%
# Actualizar un valor asignado a una clave
edades["Juan"] = 36

# %%
edades
# Out:
# {'Juan': 36, 'Esteban': 35, 'Maria': 29, 'Paco': 21}

# %%
# Otro ejemplo mas! Selección de España 2010
futbolistas = {
    1 : "Casillas", 15 : "Ramos",
    3 : "Pique", 5 : "Puyol",
    11 : "Capdevila", 14 : "Xabi Alonso",
    16 : "Busquets", 8 : "Xavi Hernandez",
    18 : "Pedrito", 6 : "Iniesta",
    7 : "Villa"
}

# %%
futbolistas
# Out:
# {1: 'Casillas',
#  15: 'Ramos',
#  3: 'Pique',
#  5: 'Puyol',
#  11: 'Capdevila',
#  14: 'Xabi Alonso',
#  16: 'Busquets',
#  8: 'Xavi Hernandez',
#  18: 'Pedrito',
#  6: 'Iniesta',
#  7: 'Villa'}

# %%
futbolistas[21] = "Pepe"

# %%
futbolistas
# Out:
# {1: 'Casillas',
#  15: 'Ramos',
#  3: 'Pique',
#  5: 'Puyol',
#  11: 'Capdevila',
#  14: 'Xabi Alonso',
#  16: 'Busquets',
#  8: 'Xavi Hernandez',
#  18: 'Pedrito',
#  6: 'Iniesta',
#  7: 'Villa',
#  21: 'Pepe'}

# %%
del futbolistas[5]

# %%
futbolistas
# Out:
# {1: 'Casillas',
#  15: 'Ramos',
#  3: 'Pique',
#  11: 'Capdevila',
#  14: 'Xabi Alonso',
#  16: 'Busquets',
#  8: 'Xavi Hernandez',
#  18: 'Pedrito',
#  6: 'Iniesta',
#  7: 'Villa',
#  21: 'Pepe'}

# %%
futbolistas.update({1: "Super Arquero", 22: "Mejor Delantero"})

# %%
futbolistas
# Out:
# {1: 'Super Arquero',
#  15: 'Ramos',
#  3: 'Pique',
#  11: 'Capdevila',
#  14: 'Xabi Alonso',
#  16: 'Busquets',
#  8: 'Xavi Hernandez',
#  18: 'Pedrito',
#  6: 'Iniesta',
#  7: 'Villa',
#  21: 'Pepe',
#  22: 'Mejor Delantero'}

# %%
len(futbolistas)
# Out:
# 12

# %% [markdown]
# Para comprobar si existe una clave o no dentro de un diccionario, podemos usar el operador in, esta acción siempre nos devolverá como resultado un booleano. Veamos algunos ejemplos:

# %%
22 in futbolistas
# Out:
# True

# %%
# Chequeas pertenencia en llaves
"Super Arquero" in futbolistas
# Out:
# False

# %%
"Super Arquero" in futbolistas.values()
# Out:
# True

# %%
futbolistas.values()
# Out:
# dict_values(['Dibu', 'Ramos', 'Pique', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez', 'Pedrito', 'Iniesta', 'Villa', 'Pepe', 'Romario', None])

# %%
paises_capitales = {
    "Venezuela": "Caracas",
    "Brazil": "Brazilia",
    "Uruguay": "Montevideo"
}

# %%
paises_capitales
# Out:
# {'Venezuela': 'Caracas', 'Brazil': 'Brazilia', 'Uruguay': 'Montevideo'}

# %%
paises_capitales.clear()

# %%
paises_capitales
# Out:
# {}

# %%
type(paises_capitales)
# Out:
# dict
